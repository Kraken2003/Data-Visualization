# %% [markdown]
# <a href="https://colab.research.google.com/github/Kraken2003/Data-Visualization/blob/main/Ecnometrics_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Econometrics /big data/good data.csv')
df
# Out:
#       Country Name Country Code  \
# 0            India          IND
# 1            India          IND
# 2            India          IND
# 3            India          IND
# 4            India          IND
# ..             ...          ...
# 863  United States          USA
# 864  United States          USA
# 865  United States          USA
# 866  United States          USA
# 867  United States          USA
#
#                                            Series Name           Series Code  \
# 0                         Population growth (annual %)           SP.POP.GROW
# 1    Population density (people per sq. km of land ...           EN.POP.DNST
# 2    Poverty headcount ratio at national poverty li...           SI.POV.NAHC
# 3    Poverty headcount ratio at $2.15 a day (2017 P...           SI.POV.DDAY
# 4                      Income share held by lowest 20%        SI.DST.FRST.20
# ..                                                 ...                   ...
# ...

# %%
sname = df['Series Name'].iloc[0:62].tolist()
scodes = df['Series Code'].iloc[0:62].tolist()
metrics = {sname[i]: scodes[i] for i in range(len(sname))}
cname = df['Country Name'].unique()
ccodes = df['Country Code'].unique()
countries = {cname[i]:ccodes[i] for i in range(len(cname))}

# %%
metrics
# Out:
# {'Population growth (annual %)': 'SP.POP.GROW',
#  'Population density (people per sq. km of land area)': 'EN.POP.DNST',
#  'Poverty headcount ratio at national poverty lines (% of population)': 'SI.POV.NAHC',
#  'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)': 'SI.POV.DDAY',
#  'Income share held by lowest 20%': 'SI.DST.FRST.20',
#  'Life expectancy at birth, total (years)': 'SP.DYN.LE00.IN',
#  'Fertility rate, total (births per woman)': 'SP.DYN.TFRT.IN',
#  'Adolescent fertility rate (births per 1,000 women ages 15-19)': 'SP.ADO.TFRT',
#  'Mortality rate, under-5 (per 1,000 live births)': 'SH.DYN.MORT',
#  'Prevalence of underweight, weight for age (% of children under 5)': 'SH.STA.MALN.ZS',
#  'School enrollment, secondary (% gross)': 'SE.SEC.ENRR',
#  'School enrollment, primary and secondary (gross), gender parity index (GPI)': 'SE.ENR.PRSC.FM.ZS',
#  'Forest area (sq. km)': 'AG.LND.FRST.K2',
# ...

# %%
countries
# Out:
# {'India': 'IND',
#  'Ireland': 'IRL',
#  'Israel': 'ISR',
#  'Korea, Rep.': 'KOR',
#  'Japan': 'JPN',
#  'Indonesia': 'IDN',
#  'France': 'FRA',
#  'Germany': 'DEU',
#  'China': 'CHN',
#  'Bangladesh': 'BGD',
#  'Pakistan': 'PAK',
#  'South Africa': 'ZAF',
#  'Sri Lanka': 'LKA',
#  'United States': 'USA'}

# %%
def compare_series(country_code1, country_code2, series_code):

    country1_data = df[(df['Country Code'] == country_code1) & (df['Series Code'] == series_code)]
    country2_data = df[(df['Country Code'] == country_code2) & (df['Series Code'] == series_code)]

    series_name = country1_data['Series Name'].iloc[0]

    country1_data_melted = country1_data.melt(id_vars=['Country Name'], value_vars=df.columns[4:], var_name='Year', value_name=series_name)
    country2_data_melted = country2_data.melt(id_vars=['Country Name'], value_vars=df.columns[4:], var_name='Year', value_name=series_name)

    plt.figure(figsize=(12, 6))
    sns.set_theme(style = 'darkgrid')
    sns.lineplot(data=country1_data_melted, x='Year', y=series_name, hue='Country Name',palette=['red'])
    sns.lineplot(data=country2_data_melted, x='Year', y=series_name, hue='Country Name',palette=['blue'])

    plt.title(f'{series_name} Comparison: {country_code1} vs {country_code2}')
    plt.xlabel('Year')
    plt.ylabel(series_name)
    plt.legend(title='Country Name')
    plt.gca().xaxis.set_major_locator(plt.MaxNLocator(10))
    plt.show()

# %%
compare_series('IND', 'BGD', 'NE.EXP.GNFS.ZS')
